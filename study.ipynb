# %%
print("자료구조")
# Out:
# 자료구조

# %%
a = ["주슥이", "티노", "티노충"]

def Myappend(n):
  a.append(n)

def Mypop():
  x = a[len(a)-1]
  del(a[len(a)-1])
  return x

def Myreverse(a):
  b = []
  for i in range(len(a)):
    b.append(a[len(a) - 1 - i])
  return b

def Myindex(n):
  for i in range(len(a)):
    if(a[i] == n):
      return i

'''
def Myinsert(location, n):
  isLocal = False;
  a1 = []
  a2 = []
  b = []
  for i in range(len(a)):
    if(isLocal == False):
      a1.append(a[i])
      if(i == (location - 2)):
        isLocal = True
    else:
      a2.append(a[i])
  b = a1 + [n] + a2
  return b
'''

def Myinsert(location, n):
  a.append('')
  for i in range(location - 1, len(a)-1):
    a[(len(a)-1 - i)+1] = a[(len(a)-1 - i)]
  a[location-1] = n
  return a

def Myremove(n):
  del(a[Myindex(n)])
  return a

def Mycount(n):
  count = 0
  for i in range(len(a)):
    if(a[i] == n):
      count = count + 1
  return count

def Mylen():
  return len(a)

print(a)
print(Myreverse(a))
print(Myindex('병신'))
print(Myinsert(2, '티모충'))
print(Myremove('티노'))
a = ["주슥이", "티노", "티노충"]
print(Mycount('티노'))
print(Mylen())
# Out:
# ['주슥이', '티노', '티노충']
# ['티노충', '티노', '주슥이']
# None
# ['주슥이', '티모충', '티노', '티노충']
# ['주슥이', '티모충', '티노충']
# 1
# 3
