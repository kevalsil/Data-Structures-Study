# %%
#커밋1단계
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#커밋2단계
cd /MyDrive/Colab Notebooks/Data_Structure/Data-Structures-Study
# Out:
#   File "<ipython-input-6-b0badf15f390>", line 2
#     cd /MyDrive/Colab Notebooks/Data_Structure/Data-Structures-Study
#                       ^
# SyntaxError: invalid syntax

# %%
#커밋3단계
# !git config --global user.email 'koreaminsoo@naver.com'
# !git config --global user.name 'kevalsil'

# %%
#커밋4단계
# !git add study.ipynb

# %%
#커밋5단계
# !git commit -m '원하는 아무 메시지'
# !git push
